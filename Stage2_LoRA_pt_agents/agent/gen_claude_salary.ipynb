# %%
! pip install pyautogen
# Out:
# Requirement already satisfied: pyautogen in d:\python\lib\site-packages (0.8.7)
# Requirement already satisfied: anyio<5.0.0,>=3.0.0 in d:\python\lib\site-packages (from pyautogen) (4.3.0)
# Requirement already satisfied: asyncer==0.0.8 in d:\python\lib\site-packages (from pyautogen) (0.0.8)
# Requirement already satisfied: diskcache in d:\python\lib\site-packages (from pyautogen) (5.6.3)
# Requirement already satisfied: docker in d:\python\lib\site-packages (from pyautogen) (7.1.0)
# Requirement already satisfied: httpx<1,>=0.28.1 in d:\python\lib\site-packages (from pyautogen) (0.28.1)
# Requirement already satisfied: packaging in d:\python\lib\site-packages (from pyautogen) (24.0)
# Requirement already satisfied: pydantic<3,>=2.6.1 in d:\python\lib\site-packages (from pyautogen) (2.10.6)
# Requirement already satisfied: python-dotenv in d:\python\lib\site-packages (from pyautogen) (1.1.0)
# Requirement already satisfied: termcolor in d:\python\lib\site-packages (from pyautogen) (2.4.0)
# Requirement already satisfied: tiktoken in d:\python\lib\site-packages (from pyautogen) (0.9.0)
# Requirement already satisfied: idna>=2.8 in d:\python\lib\site-packages (from anyio<5.0.0,>=3.0.0->pyautogen) (3.6)
# Requirement already satisfied: sniffio>=1.1 in d:\python\lib\site-packages (from anyio<5.0.0,>=3.0.0->pyautogen) (1.3.1)
# Requirement already satisfied: certifi in d:\python\lib\site-packages (from httpx<1,>=0.28.1->pyautogen) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in d:\python\lib\site-packages (from httpx<1,>=0.28.1->pyautogen) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in d:\python\lib\site-packages (from httpcore==1.*->httpx<1,>=0.28.1->pyautogen) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\python\lib\site-packages (from pydantic<3,>=2.6.1->pyautogen) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in d:\python\lib\site-packages (from pydantic<3,>=2.6.1->pyautogen) (2.27.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in d:\python\lib\site-packages (from pydantic<3,>=2.6.1->pyautogen) (4.12.2)
# Requirement already satisfied: pywin32>=304 in d:\python\lib\site-packages (from docker->pyautogen) (306)
# Requirement already satisfied: requests>=2.26.0 in d:\python\lib\site-packages (from docker->pyautogen) (2.31.0)
# Requirement already satisfied: urllib3>=1.26.0 in d:\python\lib\site-packages (from docker->pyautogen) (2.2.1)
# Requirement already satisfied: regex>=2022.1.18 in d:\python\lib\site-packages (from tiktoken->pyautogen) (2024.11.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\python\lib\site-packages (from requests>=2.26.0->docker->pyautogen) (3.3.2)

# %%
import os
import re

import autogen
import json
import pandas as pd

import time  
start_time = time.time()  

import logging
logging.basicConfig(level=logging.ERROR)

# Put your api key in the environment variable OPENAI_API_KEY
llm_config = {
    "model": "claude-3-5-sonnet-20241022",
    "api_key": "",
    "base_url": "https://api.anthropic.com/",
    "api_type": "anthropic",
}

# %%
# Create Agents, GroupChat, and GroupChatManager in line with the original group chat
gpt4_config = llm_config

# User Proxy Agent
user_proxy = autogen.UserProxyAgent(
    name="User",
    human_input_mode="NEVER",  
    max_consecutive_auto_reply=3,  
    code_execution_config=False,
)

# Planner Agent
planner = autogen.AssistantAgent(
    name="Planner",
    llm_config=llm_config,
    system_message="""
You are a task router. Based on the user's instruction, route the task as follows:

1. If the instruction contains "Extract salary information from the job ad", respond with SALARY. This task should be handled by the Salary Agent.
2. If the instruction contains "Extract seniority level from the job ad", respond with SENIORITY. This task should be handled by the Seniority Agent.
3. If the instruction contains "Extract work arrangement from the job ad", respond with ARRANGEMENT. This task should be handled by the Arrangement Agent.

Do not ask the user for clarification. Just respond with one keyword: SALARY, SENIORITY, or ARRANGEMENT.

If you receive 'TERMINATE' or the task is completed, end the conversation immediately.
"""
)

# Salary Agent
salary_agent = autogen.AssistantAgent(
    name="Salary",
    llm_config=llm_config,
    system_message="""You specialize in extracting salary information from job advertisements. Your output must follow the format below:
    STRICT OUTPUT RULES:
    1. If salary info exists: [min]-[max]-[currency]-[time_unit] (e.g., 32-45-AUD-HOURLY)
    2. If no salary info: 0-0-None-None
    3. NEVER add any explanations, notes or additional text
    4. NEVER respond to any other questions
    
    Example valid outputs:
    80000-100000-USD-YEARLY
    15-20-EUR-HOURLY 
    0-0-None-None"""
)

# Seniority Agent
seniority_agent = autogen.AssistantAgent(
    name="Seniority",
    llm_config=llm_config,
    system_message="""You specialize in extracting seniority level information from job advertisements.
    You must choose the most appropriate seniority level from the following list:
    experienced, intermediate, senior, entry level, assistant, lead, head, junior, graduate, trainee, associate, principal, apprentice, executive, manager, director, entry-level, chief, deputy, mid-level, specialist, experienced assistant, supervisor, qualified, student, board, graduate/junior, senior associate, mid-senior
    Only extract the seniority level. Do not respond to any other questions."""
)

# Arrangement Agent
arrangement_agent = autogen.AssistantAgent(
    name="Arrangement",
    llm_config=llm_config,
    system_message="""You specialize in extracting work arrangement information from job advertisements. Your output must be one of the following options:
    OnSite, Remote, Hybrid
    If the work arrangement cannot be determined, return UNKNOWN.
    Do not output full sentences or explanations. The output must be a single word only!
    Only extract the work arrangement. Do not respond to any other questions."""
)

# Critic Agent
critic_agent = autogen.AssistantAgent(
    name="Critic",
    llm_config=llm_config,
    system_message="""You are responsible for verifying whether the outputs from other agents meet the required format:

1. For Salary Agent: Must be in format "number-number-currency-time_unit" or "0-0-None-None"
2. For Seniority Agent: Must be one of the predefined seniority levels
3. For Arrangement Agent: Must be OnSite, Hybrid, Remote, or UNKNOWN

If the output is valid, respond with exactly: TERMINATE

If the output is invalid, respond with exactly: INVALID

Do not add any additional commentary or instructions."""
)

groupchat = autogen.GroupChat(
    agents=[user_proxy, planner, salary_agent, critic_agent],  
    messages=[],
    max_round=6,  
    speaker_selection_method="round_robin"  
)

manager = autogen.GroupChatManager(groupchat=groupchat, llm_config=llm_config)

def print_groupchat_log(groupchat):
    print("\n📜 GroupChat Log:")
    for idx, msg in enumerate(groupchat.messages):
        name = msg.get("name", "Unknown")
        content = msg.get("content", "").strip()
        print(f"🔹 [{idx+1}] {name}: {content[:200]}{'...' if len(content) > 200 else ''}")

def process_prompt(prompt_text):
    plan_reply = planner.initiate_chat(recipient=manager, message=prompt_text)
    route = plan_reply.summary.strip().upper()

    print_groupchat_log(groupchat)  

    if route == "SALARY":
        worker = salary_agent
    elif route == "SENIORITY":
        worker = seniority_agent
    elif route == "ARRANGEMENT":
        worker = arrangement_agent
    else:
        return None

    worker_reply = worker.initiate_chat(recipient=manager, message=prompt_text)
    chat_content = worker_reply.chat_history[-1]["content"].strip()
    extraction = chat_content

    print_groupchat_log(groupchat)  

    critic_reply = critic_agent.initiate_chat(recipient=manager, message=worker_reply.chat_history[-1]["content"])

    print_groupchat_log(groupchat)  

    return {
        "route": route,
        "extracted": extraction,
        "critic": critic_reply.summary.strip()
    }

def get_salary_output(prompt_text):
    chat_result = user_proxy.initiate_chat(
        manager,
        message=prompt_text,
        silent=True,
        max_turns=4  
    )
    
    for msg in reversed(chat_result.chat_history):
        if msg.get("name") == "Salary":
            content = msg["content"].strip()
            if re.match(r"\d+-\d+-[A-Z]+-[A-Z]+|0-0-None-None", content):
                return content
            match = re.search(r"(\d+-\d+-[A-Z]+-[A-Z]+|0-0-None-None)", content)
            if match:
                return match.group(1)
    
    return "0-0-None-None"  

with open('salary_test_combined.json', 'r', encoding='utf-8') as f:
    data = json.load(f)

print("✅ y_true values from JSON (Expected):")
for i in range(5):  
    entry = data[i]
    expected = entry['complete']
    print(f"Item {i+1} - y_true: {expected}")

results = []
for i, entry in enumerate(data):
    entry = data[i]
    prompt = entry['prompt']
    expected = entry['complete']
    
    print(f"\n🔍 Processing item {i+1}:")
    
    try:
        start_item_time = time.time()  
        
        predicted = get_salary_output(prompt)

        end_item_time = time.time()  
        elapsed_item = end_item_time - start_item_time
        
        print("✅ Extracted salary:", predicted)
        print(f"⏱️ Time used: {elapsed_item:.2f} seconds")
        
    except Exception as e:
        print("❌ Error:", e)
        predicted = "ERROR"
        elapsed_item = None  
    
    results.append({
        "index": i,
        "y_true": expected,
        "y_predicted": predicted,
        "time_seconds": round(elapsed_item, 2) if elapsed_item is not None else "ERROR"
    })

df = pd.DataFrame(results)
print("\n📋 Results Table:")
print(df)

df.to_csv("salary_predictions.csv", index=False)

end_time = time.time()
elapsed = end_time - start_time
print(f"\n⏱️ Total time consumption：{elapsed:.2f} second ({elapsed/60:.2f} minutes)")
# Out:
# ✅ y_true values from JSON (Expected):
# Item 1 - y_true: 1500-1800-MYR-MONTHLY
# Item 2 - y_true: 60-60-HKD-HOURLY
# Item 3 - y_true: 0-0-None-None
# Item 4 - y_true: 0-0-None-None
# Item 5 - y_true: 0-0-None-None
#
# 🔍 Processing item 1:
#
# Next speaker: Planner
#
# Planner (to chat_manager):
#
# SALARY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Salary
#
# Salary (to chat_manager):
#
# 1500-1800-MYR-MONTHLY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Critic
#
# Critic (to chat_manager):
#
# TERMINATE
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (98d2b036-f2b8-4a11-841c-0047687de9ce): Termination message condition on the GroupChatManager 'chat_manager' met
#
# >>>>>>>> TERMINATING RUN (1a38efb1-ef45-4c4d-b88d-4557e3d431a4): Termination message condition on agent 'User' met
# ✅ Extracted salary: 1500-1800-MYR-MONTHLY
# ⏱️ Time used: 6.03 秒
#
# 🔍 Processing item 2:
#
# Next speaker: Planner
#
# Planner (to chat_manager):
#
# SALARY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Salary
#
# Salary (to chat_manager):
#
# 60-60-HKD-HOURLY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Critic
#
# Critic (to chat_manager):
#
# TERMINATE
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (180116da-9a64-464d-8dc4-5d7fc96a0013): Termination message condition on the GroupChatManager 'chat_manager' met
#
# >>>>>>>> TERMINATING RUN (13f672de-6771-43eb-a840-828bccf76596): Termination message condition on agent 'User' met
# ✅ Extracted salary: 60-60-HKD-HOURLY
# ⏱️ Time used: 9.58 秒
#
# 🔍 Processing item 3:
#
# Next speaker: Planner
#
# Planner (to chat_manager):
#
# SALARY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Salary
#
# Salary (to chat_manager):
#
# 0-0-None-None
#
# --------------------------------------------------------------------------------
#
# Next speaker: Critic
#
# Critic (to chat_manager):
#
# TERMINATE
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (d7dbe180-022c-4ddd-80a0-d05a08036527): Termination message condition on the GroupChatManager 'chat_manager' met
#
# >>>>>>>> TERMINATING RUN (aaf51cbe-e765-4b38-9c14-dd1f3f85393a): Termination message condition on agent 'User' met
# ✅ Extracted salary: 0-0-None-None
# ⏱️ Time used: 7.68 秒
#
# 🔍 Processing item 4:
#
# Next speaker: Planner
#
# Planner (to chat_manager):
#
# SALARY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Salary
#
# Salary (to chat_manager):
#
# 0-0-None-None
#
# --------------------------------------------------------------------------------
#
# Next speaker: Critic
#
# Critic (to chat_manager):
#
# TERMINATE
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (38439230-1450-4772-94d6-185bd10c7fc8): Termination message condition on the GroupChatManager 'chat_manager' met
#
# >>>>>>>> TERMINATING RUN (d2b31575-9bac-43b2-8db3-6d7496ef73d8): Termination message condition on agent 'User' met
# ✅ Extracted salary: 0-0-None-None
# ⏱️ Time used: 10.46 秒
#
# 🔍 Processing item 5:
#
# Next speaker: Planner
#
# Planner (to chat_manager):
#
# SALARY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Salary
#
# Salary (to chat_manager):
#
# 0-0-None-None
#
# --------------------------------------------------------------------------------
#
# Next speaker: Critic
#
# Critic (to chat_manager):
#
# TERMINATE
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (9fcfd5ce-2387-4e7b-9165-18549ba2dc29): Termination message condition on the GroupChatManager 'chat_manager' met
#
# >>>>>>>> TERMINATING RUN (2823a91a-afcc-4ccf-b36a-7e6370c8a250): Termination message condition on agent 'User' met
# ✅ Extracted salary: 0-0-None-None
# ⏱️ Time used: 8.36 秒
#
# 🔍 Processing item 6:
#
# Next speaker: Planner
#
# Planner (to chat_manager):
#
# SALARY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Salary
#
# Salary (to chat_manager):
#
# 21.20-21.20-NZD-HOURLY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Critic
#
# Critic (to chat_manager):
#
# TERMINATE
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (a924bb15-e54a-4ed7-8b03-cd3ad8fa5c99): Termination message condition on the GroupChatManager 'chat_manager' met
#
# >>>>>>>> TERMINATING RUN (e0fd2cb9-2159-43c2-8e07-5fa2d78dd42e): Termination message condition on agent 'User' met
# ✅ Extracted salary: 0-0-None-None
# ⏱️ Time used: 10.83 秒
#
# 🔍 Processing item 7:
#
# Next speaker: Planner
#
# Planner (to chat_manager):
#
# SALARY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Salary
#
# Salary (to chat_manager):
#
# 0-0-None-None
#
# --------------------------------------------------------------------------------
#
# Next speaker: Critic
#
# Critic (to chat_manager):
#
# TERMINATE
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (e3eded2e-4577-4bee-959f-2ace1ae63e25): Termination message condition on the GroupChatManager 'chat_manager' met
#
# >>>>>>>> TERMINATING RUN (4509a7bb-a85a-44cb-be11-97c71a4379e7): Termination message condition on agent 'User' met
# ✅ Extracted salary: 0-0-None-None
# ⏱️ Time used: 7.01 秒
#
# 🔍 Processing item 8:
#
# Next speaker: Planner
#
# Planner (to chat_manager):
#
# SALARY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Salary
#
# Salary (to chat_manager):
#
# 0-0-None-None
#
# --------------------------------------------------------------------------------
#
# Next speaker: Critic
#
# Critic (to chat_manager):
#
# TERMINATE
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (20f480e1-5567-4a4e-b5d0-90e588ced1bf): Termination message condition on the GroupChatManager 'chat_manager' met
#
# >>>>>>>> TERMINATING RUN (23e64df2-78dd-42e2-9f50-7bef15347400): Termination message condition on agent 'User' met
# ✅ Extracted salary: 0-0-None-None
# ⏱️ Time used: 8.65 秒
#
# 🔍 Processing item 9:
#
# Next speaker: Planner
#
# Planner (to chat_manager):
#
# SALARY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Salary
#
# Salary (to chat_manager):
#
# 32.42-32.42-AUD-HOURLY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Critic
#
# Critic (to chat_manager):
#
# TERMINATE
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (94615bcb-ec29-4ced-bce1-7c8feb316980): Termination message condition on the GroupChatManager 'chat_manager' met
#
# >>>>>>>> TERMINATING RUN (26c4756b-5580-4d1c-82ba-50638bdcb8de): Termination message condition on agent 'User' met
# ✅ Extracted salary: 0-0-None-None
# ⏱️ Time used: 8.56 秒
#
# 🔍 Processing item 10:
#
# Next speaker: Planner
#
# Planner (to chat_manager):
#
# SALARY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Salary
#
# Salary (to chat_manager):
#
# 2000-3000-MYR-MONTHLY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Critic
#
# Critic (to chat_manager):
#
# TERMINATE
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (4d472bb1-2f1f-40a7-96f8-9ba32f14cfc6): Termination message condition on the GroupChatManager 'chat_manager' met
#
# >>>>>>>> TERMINATING RUN (cbf56993-fe9f-4bd0-800a-ad6253e1daa9): Termination message condition on agent 'User' met
# ✅ Extracted salary: 2000-3000-MYR-MONTHLY
# ⏱️ Time used: 8.56 秒
#
# 🔍 Processing item 11:
#
# Next speaker: Planner
#
# Planner (to chat_manager):
#
# SALARY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Salary
#
# Salary (to chat_manager):
#
# 3000-4000-MYR-MONTHLY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Critic
#
# Critic (to chat_manager):
#
# TERMINATE
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (313f1090-6489-4e58-924c-85f086b15627): Termination message condition on the GroupChatManager 'chat_manager' met
#
# >>>>>>>> TERMINATING RUN (1f807cd2-d8ec-4be2-908b-34b09941b737): Termination message condition on agent 'User' met
# ✅ Extracted salary: 3000-4000-MYR-MONTHLY
# ⏱️ Time used: 9.35 秒
#
# 🔍 Processing item 12:
#
# Next speaker: Planner
#
# Planner (to chat_manager):
#
# SALARY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Salary
#
# Salary (to chat_manager):
#
# 0-0-None-None
#
# --------------------------------------------------------------------------------
#
# Next speaker: Critic
#
# Critic (to chat_manager):
#
# TERMINATE
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (e03d0792-f93b-46ce-873c-05f462366ad4): Termination message condition on the GroupChatManager 'chat_manager' met
#
# >>>>>>>> TERMINATING RUN (c5dcf2c2-bb59-4757-b68e-3fc3310ca1e8): Termination message condition on agent 'User' met
# ✅ Extracted salary: 0-0-None-None
# ⏱️ Time used: 9.74 秒
#
# 🔍 Processing item 13:
#
# Next speaker: Planner
#
# Planner (to chat_manager):
#
# SALARY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Salary
#
# Salary (to chat_manager):
#
# 0-0-None-None
#
# --------------------------------------------------------------------------------
#
# Next speaker: Critic
#
# Critic (to chat_manager):
#
# TERMINATE
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (58b4cc4c-66bb-4d6d-bbe1-73f652c0ba0e): Termination message condition on the GroupChatManager 'chat_manager' met
#
# >>>>>>>> TERMINATING RUN (13a8caef-f793-4d17-b3fd-f5f2cbae8463): Termination message condition on agent 'User' met
# ✅ Extracted salary: 0-0-None-None
# ⏱️ Time used: 9.79 秒
#
# 🔍 Processing item 14:
#
# Next speaker: Planner
#
# Planner (to chat_manager):
#
# SALARY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Salary
#
# Salary (to chat_manager):
#
# 80-90-HKD-HOURLY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Critic
#
# Critic (to chat_manager):
#
# TERMINATE
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (9bc8ed56-68e2-48fe-850b-232d9794fd08): Termination message condition on the GroupChatManager 'chat_manager' met
#
# >>>>>>>> TERMINATING RUN (452624ba-25a7-4bb0-bca2-6523342d8f39): Termination message condition on agent 'User' met
# ✅ Extracted salary: 80-90-HKD-HOURLY
# ⏱️ Time used: 36.57 秒
#
# 🔍 Processing item 15:
#
# Next speaker: Planner
#
# Planner (to chat_manager):
#
# SALARY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Salary
#
# Salary (to chat_manager):
#
# 142642-156491-AUD-YEARLY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Critic
#
# Critic (to chat_manager):
#
# TERMINATE
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (4d0dfcda-8cef-45f8-b51b-bac9839814f9): Termination message condition on the GroupChatManager 'chat_manager' met
#
# >>>>>>>> TERMINATING RUN (9d92216f-8656-4229-b555-3fe9224a3bb3): Termination message condition on agent 'User' met
# ✅ Extracted salary: 142642-156491-AUD-YEARLY
# ⏱️ Time used: 10.68 秒
#
# 🔍 Processing item 16:
#
# Next speaker: Planner
#
# Planner (to chat_manager):
#
# SALARY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Salary
#
# Salary (to chat_manager):
#
# 0-0-None-None
#
# --------------------------------------------------------------------------------
#
# Next speaker: Critic
#
# Critic (to chat_manager):
#
# TERMINATE
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (f61116ab-8aa3-415b-a1fc-f41b762769c5): Termination message condition on the GroupChatManager 'chat_manager' met
#
# >>>>>>>> TERMINATING RUN (3ff2c332-27cf-4e27-802d-3dac34737eff): Termination message condition on agent 'User' met
# ✅ Extracted salary: 0-0-None-None
# ⏱️ Time used: 17.34 秒
#
# 🔍 Processing item 17:
#
# Next speaker: Planner
#
# Planner (to chat_manager):
#
# SALARY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Salary
#
# Salary (to chat_manager):
#
# 28.80-28.80-AUD-HOURLY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Critic
#
# Critic (to chat_manager):
#
# TERMINATE
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (d5344b30-f04c-4926-b71e-62a72d22df01): Termination message condition on the GroupChatManager 'chat_manager' met
#
# >>>>>>>> TERMINATING RUN (8234e0bf-d62e-42d4-9683-3825bc40eeb8): Termination message condition on agent 'User' met
# ✅ Extracted salary: 0-0-None-None
# ⏱️ Time used: 15.83 秒
#
# 🔍 Processing item 18:
#
# Next speaker: Planner
#
# Planner (to chat_manager):
#
# SALARY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Salary
#
# Salary (to chat_manager):
#
# 1500-2500-MYR-MONTHLY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Critic
#
# Critic (to chat_manager):
#
# TERMINATE
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (43ad4c80-4ff0-447e-8b26-b69fe33d58de): Termination message condition on the GroupChatManager 'chat_manager' met
#
# >>>>>>>> TERMINATING RUN (ded178ca-770b-4840-a06b-78b724146413): Termination message condition on agent 'User' met
# ✅ Extracted salary: 1500-2500-MYR-MONTHLY
# ⏱️ Time used: 10.57 秒
#
# 🔍 Processing item 19:
#
# Next speaker: Planner
#
# Planner (to chat_manager):
#
# SALARY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Salary
#
# Salary (to chat_manager):
#
# 66027-68085-AUD-YEARLY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Critic
#
# Critic (to chat_manager):
#
# TERMINATE
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (eb4384e5-d82a-41c2-bfc9-ab255bcf443d): Termination message condition on the GroupChatManager 'chat_manager' met
#
# >>>>>>>> TERMINATING RUN (89ff653c-d1c3-4704-bf53-71d91a1b4269): Termination message condition on agent 'User' met
# ✅ Extracted salary: 66027-68085-AUD-YEARLY
# ⏱️ Time used: 11.65 秒
#
# 🔍 Processing item 20:
#
# Next speaker: Planner
#
# Planner (to chat_manager):
#
# SALARY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Salary
#
# Salary (to chat_manager):
#
# 0-0-None-None
#
# --------------------------------------------------------------------------------
#
# Next speaker: Critic
#
# Critic (to chat_manager):
#
# TERMINATE
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (64aebc6b-9252-47c2-a7c1-3ffb4ca403c3): Termination message condition on the GroupChatManager 'chat_manager' met
#
# >>>>>>>> TERMINATING RUN (e9aea65a-8e22-42f0-8f49-f94fa9b26e2b): Termination message condition on agent 'User' met
# ✅ Extracted salary: 0-0-None-None
# ⏱️ Time used: 19.41 秒
#
# 🔍 Processing item 21:
#
# Next speaker: Planner
#
# Planner (to chat_manager):
#
# SALARY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Salary
#
# Salary (to chat_manager):
#
# 3000-4000-USD-MONTHLY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Critic
#
# Critic (to chat_manager):
#
# TERMINATE
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (dcb826b2-6bad-4c94-acd6-b8f428e54214): Termination message condition on the GroupChatManager 'chat_manager' met
#
# >>>>>>>> TERMINATING RUN (fbeb73e5-2afd-4f2a-9e19-ff32fe848601): Termination message condition on agent 'User' met
# ✅ Extracted salary: 3000-4000-USD-MONTHLY
# ⏱️ Time used: 11.68 秒
#
# 🔍 Processing item 22:
#
# Next speaker: Planner
#
# Planner (to chat_manager):
#
# SALARY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Salary
#
# Salary (to chat_manager):
#
# 0-0-None-None
#
# --------------------------------------------------------------------------------
#
# Next speaker: Critic
#
# Critic (to chat_manager):
#
# TERMINATE
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (bcf4c6c4-a392-4e5d-8499-2bb629f22fd8): Termination message condition on the GroupChatManager 'chat_manager' met
#
# >>>>>>>> TERMINATING RUN (7bd164ca-4649-47e2-a221-f5f411bfd57d): Termination message condition on agent 'User' met
# ✅ Extracted salary: 0-0-None-None
# ⏱️ Time used: 10.15 秒
#
# 🔍 Processing item 23:
#
# Next speaker: Planner
#
# Planner (to chat_manager):
#
# SALARY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Salary
#
# Salary (to chat_manager):
#
# 0-0-None-None
#
# --------------------------------------------------------------------------------
#
# Next speaker: Critic
#
# Critic (to chat_manager):
#
# TERMINATE
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (8f2e4a8d-6543-4ffd-a791-2e2713e1eaed): Termination message condition on the GroupChatManager 'chat_manager' met
#
# >>>>>>>> TERMINATING RUN (284ea539-43d8-4cf6-b4fe-c9bd3ec1190f): Termination message condition on agent 'User' met
# ✅ Extracted salary: 0-0-None-None
# ⏱️ Time used: 10.55 秒
#
# 🔍 Processing item 24:
#
# Next speaker: Planner
#
# Planner (to chat_manager):
#
# SALARY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Salary
#
# Salary (to chat_manager):
#
# 73-85-HKD-HOURLY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Critic
#
# Critic (to chat_manager):
#
# TERMINATE
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (60e28f2c-4b93-4a80-9346-f15816ba9cf3): Termination message condition on the GroupChatManager 'chat_manager' met
#
# >>>>>>>> TERMINATING RUN (97fd660d-8873-47b4-8eb1-2d8969981b0b): Termination message condition on agent 'User' met
# ✅ Extracted salary: 73-85-HKD-HOURLY
# ⏱️ Time used: 7.89 秒
#
# 🔍 Processing item 25:
#
# Next speaker: Planner
#
# Planner (to chat_manager):
#
# SALARY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Salary
#
# Salary (to chat_manager):
#
# 5000-8000-MYR-MONTHLY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Critic
#
# Critic (to chat_manager):
#
# TERMINATE
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (170f2750-44b4-4f6f-aec2-0aaacb4fab9a): Termination message condition on the GroupChatManager 'chat_manager' met
#
# >>>>>>>> TERMINATING RUN (82da0fde-e34c-4c10-8f7c-131d35921e8d): Termination message condition on agent 'User' met
# ✅ Extracted salary: 5000-8000-MYR-MONTHLY
# ⏱️ Time used: 7.65 秒
#
# 🔍 Processing item 26:
#
# Next speaker: Planner
#
# Planner (to chat_manager):
#
# SALARY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Salary
#
# Salary (to chat_manager):
#
# 0-0-None-None
#
# --------------------------------------------------------------------------------
#
# Next speaker: Critic
#
# Critic (to chat_manager):
#
# TERMINATE
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (4ef16b34-651d-4e48-8da0-175ec6d70f0b): Termination message condition on the GroupChatManager 'chat_manager' met
#
# >>>>>>>> TERMINATING RUN (d934995b-956d-453d-b62b-dfba1426d463): Termination message condition on agent 'User' met
# ✅ Extracted salary: 0-0-None-None
# ⏱️ Time used: 5.48 秒
#
# 🔍 Processing item 27:
#
# Next speaker: Planner
#
# Planner (to chat_manager):
#
# SALARY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Salary
#
# Salary (to chat_manager):
#
# 0-0-None-None
#
# --------------------------------------------------------------------------------
#
# Next speaker: Critic
#
# Critic (to chat_manager):
#
# TERMINATE
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (ab203c4f-ecc9-4946-ac17-0eca6be67253): Termination message condition on the GroupChatManager 'chat_manager' met
#
# >>>>>>>> TERMINATING RUN (3e555246-d726-4633-8d53-02e1ffaa6a10): Termination message condition on agent 'User' met
# ✅ Extracted salary: 0-0-None-None
# ⏱️ Time used: 5.12 秒
#
# 🔍 Processing item 28:
#
# Next speaker: Planner
#
# Planner (to chat_manager):
#
# SALARY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Salary
#
# Salary (to chat_manager):
#
# 500-1250-SGD-WEEKLY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Critic
#
# Critic (to chat_manager):
#
# TERMINATE
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (b4dc8e7e-741b-47cf-91f7-17aa0cfb3333): Termination message condition on the GroupChatManager 'chat_manager' met
#
# >>>>>>>> TERMINATING RUN (9f4e00a4-1a07-40b8-b36c-5a99ecf2f80b): Termination message condition on agent 'User' met
# ✅ Extracted salary: 500-1250-SGD-WEEKLY
# ⏱️ Time used: 5.91 秒
#
# 🔍 Processing item 29:
#
# Next speaker: Planner
#
# Planner (to chat_manager):
#
# SALARY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Salary
#
# Salary (to chat_manager):
#
# 1500-1500-MYR-MONTHLY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Critic
#
# Critic (to chat_manager):
#
# TERMINATE
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (b4f20f37-b635-43b1-b5ed-53c53d414840): Termination message condition on the GroupChatManager 'chat_manager' met
#
# >>>>>>>> TERMINATING RUN (c9a296b5-8a29-4cbb-bfae-6843f6a4883c): Termination message condition on agent 'User' met
# ✅ Extracted salary: 1500-1500-MYR-MONTHLY
# ⏱️ Time used: 5.53 秒
#
# 🔍 Processing item 30:
#
# Next speaker: Planner
#
# Planner (to chat_manager):
#
# SALARY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Salary
#
# Salary (to chat_manager):
#
# 750-1125-SGD-WEEKLY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Critic
#
# Critic (to chat_manager):
#
# TERMINATE
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (cd7807b1-6982-410a-8777-a2cf0246ed55): Termination message condition on the GroupChatManager 'chat_manager' met
#
# >>>>>>>> TERMINATING RUN (8053964d-1e7d-4f90-91d7-f46a80842257): Termination message condition on agent 'User' met
# ✅ Extracted salary: 750-1125-SGD-WEEKLY
# ⏱️ Time used: 6.05 秒
#
# 🔍 Processing item 31:
#
# Next speaker: Planner
#
# Planner (to chat_manager):
#
# SALARY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Salary
#
# Salary (to chat_manager):
#
# 0-0-None-None
#
# --------------------------------------------------------------------------------
#
# Next speaker: Critic
#
# Critic (to chat_manager):
#
# TERMINATE
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (00f1f9ef-d4ba-4529-b64a-771540eb5479): Termination message condition on the GroupChatManager 'chat_manager' met
#
# >>>>>>>> TERMINATING RUN (4af8d7ae-df73-4539-a155-1de8ce892581): Termination message condition on agent 'User' met
# ✅ Extracted salary: 0-0-None-None
# ⏱️ Time used: 6.60 秒
#
# 🔍 Processing item 32:
#
# Next speaker: Planner
#
# Planner (to chat_manager):
#
# SALARY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Salary
#
# Salary (to chat_manager):
#
# 0-0-None-None
#
# --------------------------------------------------------------------------------
#
# Next speaker: Critic
#
# Critic (to chat_manager):
#
# TERMINATE
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (ced9184a-7400-4ad1-a8a4-e54f7aed7e88): Termination message condition on the GroupChatManager 'chat_manager' met
#
# >>>>>>>> TERMINATING RUN (168f3647-de88-4967-b2f8-8ecd95a75287): Termination message condition on agent 'User' met
# ✅ Extracted salary: 0-0-None-None
# ⏱️ Time used: 19.54 秒
#
# 🔍 Processing item 33:
#
# Next speaker: Planner
#
# Planner (to chat_manager):
#
# SALARY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Salary
#
# Salary (to chat_manager):
#
# 0-0-None-None
#
# --------------------------------------------------------------------------------
#
# Next speaker: Critic
#
# Critic (to chat_manager):
#
# TERMINATE
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (cc619cc0-e2be-4955-a559-65a62f8c371b): Termination message condition on the GroupChatManager 'chat_manager' met
#
# >>>>>>>> TERMINATING RUN (f6024218-36d6-415c-aa3f-61e6d290d154): Termination message condition on agent 'User' met
# ✅ Extracted salary: 0-0-None-None
# ⏱️ Time used: 16.15 秒
#
# 🔍 Processing item 34:
#
# Next speaker: Planner
#
# Planner (to chat_manager):
#
# SALARY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Salary
#
# Salary (to chat_manager):
#
# 1500-1500-MYR-MONTHLY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Critic
#
# Critic (to chat_manager):
#
# TERMINATE
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (1cab90d0-f75f-4b65-a193-a0f9a386bdf7): Termination message condition on the GroupChatManager 'chat_manager' met
#
# >>>>>>>> TERMINATING RUN (92f23af7-12a9-4737-9c8c-5eb5e4d780d6): Termination message condition on agent 'User' met
# ✅ Extracted salary: 1500-1500-MYR-MONTHLY
# ⏱️ Time used: 9.64 秒
#
# 🔍 Processing item 35:
#
# Next speaker: Planner
#
# Planner (to chat_manager):
#
# SALARY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Salary
#
# Salary (to chat_manager):
#
# 2000-2500-SGD-MONTHLY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Critic
#
# Critic (to chat_manager):
#
# TERMINATE
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (d2d5426b-bfd9-4662-821b-a1af95088b65): Termination message condition on the GroupChatManager 'chat_manager' met
#
# >>>>>>>> TERMINATING RUN (8c43c3c7-c4f6-4d9e-914a-2d232e1b24b2): Termination message condition on agent 'User' met
# ✅ Extracted salary: 2000-2500-SGD-MONTHLY
# ⏱️ Time used: 8.49 秒
#
# 🔍 Processing item 36:
#
# Next speaker: Planner
#
# Planner (to chat_manager):
#
# SALARY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Salary
#
# Salary (to chat_manager):
#
# 58008-68008-AUD-YEARLY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Critic
#
# Critic (to chat_manager):
#
# TERMINATE
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (e8d834e1-2892-4469-a12a-dacf62665855): Termination message condition on the GroupChatManager 'chat_manager' met
#
# >>>>>>>> TERMINATING RUN (d1fe6de3-75d7-4a2a-ad61-f81d0b5b87c1): Termination message condition on agent 'User' met
# ✅ Extracted salary: 58008-68008-AUD-YEARLY
# ⏱️ Time used: 8.92 秒
#
# 🔍 Processing item 37:
#
# Next speaker: Planner
#
# Planner (to chat_manager):
#
# SALARY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Salary
#
# Salary (to chat_manager):
#
# 23.38-29.10-NZD-HOURLY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Critic
#
# Critic (to chat_manager):
#
# TERMINATE
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (dffc13be-f209-4bf2-9b8b-3937cd4564cd): Termination message condition on the GroupChatManager 'chat_manager' met
#
# >>>>>>>> TERMINATING RUN (fe94f034-2c34-4aa6-a62e-57ae9a1e9459): Termination message condition on agent 'User' met
# ✅ Extracted salary: 0-0-None-None
# ⏱️ Time used: 7.87 秒
#
# 🔍 Processing item 38:
#
# Next speaker: Planner
#
# Planner (to chat_manager):
#
# SALARY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Salary
#
# Salary (to chat_manager):
#
# 3000-6000-MYR-MONTHLY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Critic
#
# Critic (to chat_manager):
#
# TERMINATE
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (053d2b07-342e-4333-9661-3a33e942cfa6): Termination message condition on the GroupChatManager 'chat_manager' met
#
# >>>>>>>> TERMINATING RUN (b8d4fc47-29e9-4123-86a4-26f5272082c8): Termination message condition on agent 'User' met
# ✅ Extracted salary: 3000-6000-MYR-MONTHLY
# ⏱️ Time used: 7.50 秒
#
# 🔍 Processing item 39:
#
# Next speaker: Planner
#
# Planner (to chat_manager):
#
# SALARY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Salary
#
# Salary (to chat_manager):
#
# 31-31-NZD-HOURLY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Critic
#
# Critic (to chat_manager):
#
# TERMINATE
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (c241b4a7-1074-4b03-a5d1-974abb72ce7a): Termination message condition on the GroupChatManager 'chat_manager' met
#
# >>>>>>>> TERMINATING RUN (6131ed5d-d70c-4000-b1c4-f047e0c91b3f): Termination message condition on agent 'User' met
# ✅ Extracted salary: 31-31-NZD-HOURLY
# ⏱️ Time used: 7.69 秒
#
# 🔍 Processing item 40:
#
# Next speaker: Planner
#
# Planner (to chat_manager):
#
# SALARY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Salary
#
# Salary (to chat_manager):
#
# 100-100-HKD-HOURLY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Critic
#
# Critic (to chat_manager):
#
# TERMINATE
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (98b42efb-b4a2-49b6-bf18-12cf67d68f01): Termination message condition on the GroupChatManager 'chat_manager' met
#
# >>>>>>>> TERMINATING RUN (328b6d87-2b85-4068-9d7a-a3cc2d8e3ca5): Termination message condition on agent 'User' met
# ✅ Extracted salary: 100-100-HKD-HOURLY
# ⏱️ Time used: 15.02 秒
#
# 🔍 Processing item 41:
#
# Next speaker: Planner
#
# Planner (to chat_manager):
#
# SALARY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Salary
#
# Salary (to chat_manager):
#
# 500-667-PHP-DAILY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Critic
#
# Critic (to chat_manager):
#
# TERMINATE
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (41d6ab93-7600-4995-b39f-8266b8e886f8): Termination message condition on the GroupChatManager 'chat_manager' met
#
# >>>>>>>> TERMINATING RUN (0b7316fe-215e-44e6-8c8b-4015247e45bb): Termination message condition on agent 'User' met
# ✅ Extracted salary: 500-667-PHP-DAILY
# ⏱️ Time used: 12.34 秒
#
# 🔍 Processing item 42:
#
# Next speaker: Planner
#
# Planner (to chat_manager):
#
# SALARY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Salary
#
# Salary (to chat_manager):
#
# 107-150-SGD-DAILY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Critic
#
# Critic (to chat_manager):
#
# TERMINATE
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (0e823450-44fa-4083-bd51-a2389816d2fe): Termination message condition on the GroupChatManager 'chat_manager' met
#
# >>>>>>>> TERMINATING RUN (24d7f331-9c33-44a2-bc60-fdc0d42254a9): Termination message condition on agent 'User' met
# ✅ Extracted salary: 107-150-SGD-DAILY
# ⏱️ Time used: 14.18 秒
#
# 🔍 Processing item 43:
#
# Next speaker: Planner
#
# Planner (to chat_manager):
#
# SALARY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Salary
#
# Salary (to chat_manager):
#
# 1500-1500-MYR-MONTHLY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Critic
#
# Critic (to chat_manager):
#
# TERMINATE
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (c3bd329d-6f30-4e0d-a23b-e54a91c2f237): Termination message condition on the GroupChatManager 'chat_manager' met
#
# >>>>>>>> TERMINATING RUN (c8094831-f1c5-4d03-b645-04bb0572c5f9): Termination message condition on agent 'User' met
# ✅ Extracted salary: 1500-1500-MYR-MONTHLY
# ⏱️ Time used: 7.55 秒
#
# 🔍 Processing item 44:
#
# Next speaker: Planner
#
# Planner (to chat_manager):
#
# SALARY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Salary
#
# Salary (to chat_manager):
#
# 25.05-25.05-AUD-HOURLY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Critic
#
# Critic (to chat_manager):
#
# TERMINATE
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (157156de-efc7-4636-9c0a-d4e6de2ec41a): Termination message condition on the GroupChatManager 'chat_manager' met
#
# >>>>>>>> TERMINATING RUN (74c32ad7-3db2-4472-9a1d-ef96258f688e): Termination message condition on agent 'User' met
# ✅ Extracted salary: 0-0-None-None
# ⏱️ Time used: 11.88 秒
#
# 🔍 Processing item 45:
#
# Next speaker: Planner
#
# Planner (to chat_manager):
#
# SALARY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Salary
#
# Salary (to chat_manager):
#
# 0-0-None-None
#
# --------------------------------------------------------------------------------
#
# Next speaker: Critic
#
# Critic (to chat_manager):
#
# TERMINATE
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (8ce8f284-ae26-43b9-9643-7fc947301118): Termination message condition on the GroupChatManager 'chat_manager' met
#
# >>>>>>>> TERMINATING RUN (b55c3548-aa6f-4f8b-b644-d22722f37130): Termination message condition on agent 'User' met
# ✅ Extracted salary: 0-0-None-None
# ⏱️ Time used: 13.28 秒
#
# 🔍 Processing item 46:
#
# Next speaker: Planner
#
# Planner (to chat_manager):
#
# SALARY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Salary
#
# Salary (to chat_manager):
#
# 0-0-None-None
#
# --------------------------------------------------------------------------------
#
# Next speaker: Critic
#
# Critic (to chat_manager):
#
# TERMINATE
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (b78ee4bf-5c88-4f48-9d86-7bd0ca38d329): Termination message condition on the GroupChatManager 'chat_manager' met
#
# >>>>>>>> TERMINATING RUN (0710a6ba-fc9d-4835-9031-7a65de9a7616): Termination message condition on agent 'User' met
# ✅ Extracted salary: 0-0-None-None
# ⏱️ Time used: 9.60 秒
#
# 🔍 Processing item 47:
#
# Next speaker: Planner
#
# Planner (to chat_manager):
#
# SALARY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Salary
#
# Salary (to chat_manager):
#
# 2700-3000-SGD-MONTHLY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Critic
#
# Critic (to chat_manager):
#
# TERMINATE
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (10c55b39-d20e-44f5-a304-d60bdc516774): Termination message condition on the GroupChatManager 'chat_manager' met
#
# >>>>>>>> TERMINATING RUN (1b80d88a-8f6b-444b-ab1d-ed0176b6ca36): Termination message condition on agent 'User' met
# ✅ Extracted salary: 2700-3000-SGD-MONTHLY
# ⏱️ Time used: 8.64 秒
#
# 🔍 Processing item 48:
#
# Next speaker: Planner
#
# Planner (to chat_manager):
#
# SALARY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Salary
#
# Salary (to chat_manager):
#
# 0-0-None-None
#
# --------------------------------------------------------------------------------
#
# Next speaker: Critic
#
# Critic (to chat_manager):
#
# TERMINATE
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (7255cbcd-0f65-4518-9737-5546645c5534): Termination message condition on the GroupChatManager 'chat_manager' met
#
# >>>>>>>> TERMINATING RUN (921ab9d4-902c-4b4b-b76d-4df89bd9faf9): Termination message condition on agent 'User' met
# ✅ Extracted salary: 0-0-None-None
# ⏱️ Time used: 9.03 秒
#
# 🔍 Processing item 49:
#
# Next speaker: Planner
#
# Planner (to chat_manager):
#
# SALARY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Salary
#
# Salary (to chat_manager):
#
# 0-0-None-None
#
# --------------------------------------------------------------------------------
#
# Next speaker: Critic
#
# Critic (to chat_manager):
#
# TERMINATE
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (7d7d1646-ef15-43dc-b5e9-e612cb05b5ad): Termination message condition on the GroupChatManager 'chat_manager' met
#
# >>>>>>>> TERMINATING RUN (467568bf-1af0-41fe-a33e-a8453902d20f): Termination message condition on agent 'User' met
# ✅ Extracted salary: 0-0-None-None
# ⏱️ Time used: 9.79 秒
#
# 🔍 Processing item 50:
#
# Next speaker: Planner
#
# ❌ Error: Error code: 529 - {'type': 'error', 'error': {'type': 'overloaded_error', 'message': 'Overloaded'}}
#
# 🔍 Processing item 51:
#
# Next speaker: Planner
#
# Planner (to chat_manager):
#
# SALARY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Salary
#
# Salary (to chat_manager):
#
# 2300-2700-SGD-MONTHLY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Critic
#
# Critic (to chat_manager):
#
# TERMINATE
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (d9952595-f99f-42b2-84b9-23af1de52221): Termination message condition on the GroupChatManager 'chat_manager' met
#
# >>>>>>>> TERMINATING RUN (d766664b-a102-476c-b488-c34204d0d31a): Termination message condition on agent 'User' met
# ✅ Extracted salary: 2300-2700-SGD-MONTHLY
# ⏱️ Time used: 18.01 秒
#
# 🔍 Processing item 52:
#
# Next speaker: Planner
#
# Planner (to chat_manager):
#
# SALARY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Salary
#
# Salary (to chat_manager):
#
# 0-0-None-None
#
# --------------------------------------------------------------------------------
#
# Next speaker: Critic
#
# Critic (to chat_manager):
#
# TERMINATE
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (6167cc16-c407-4eca-92b6-681c2a6a5629): Termination message condition on the GroupChatManager 'chat_manager' met
#
# >>>>>>>> TERMINATING RUN (083962f8-9405-4124-bbe1-fff6f51f472b): Termination message condition on agent 'User' met
# ✅ Extracted salary: 0-0-None-None
# ⏱️ Time used: 12.11 秒
#
# 🔍 Processing item 53:
#
# Next speaker: Planner
#
# Planner (to chat_manager):
#
# SALARY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Salary
#
# Salary (to chat_manager):
#
# 61868-61868-AUD-YEARLY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Critic
#
# Critic (to chat_manager):
#
# TERMINATE
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (76b5ff3a-859d-4bad-825e-2ea205e74792): Termination message condition on the GroupChatManager 'chat_manager' met
#
# >>>>>>>> TERMINATING RUN (4fcfe965-f74e-43f9-80f8-8ce141d2dd38): Termination message condition on agent 'User' met
# ✅ Extracted salary: 61868-61868-AUD-YEARLY
# ⏱️ Time used: 21.40 秒
#
# 🔍 Processing item 54:
#
# Next speaker: Planner
#
# Planner (to chat_manager):
#
# SALARY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Salary
#
# Salary (to chat_manager):
#
# 0-0-None-None
#
# --------------------------------------------------------------------------------
#
# Next speaker: Critic
#
# Critic (to chat_manager):
#
# TERMINATE
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (1c42c309-c246-49de-bef3-3e10d95afd5e): Termination message condition on the GroupChatManager 'chat_manager' met
#
# >>>>>>>> TERMINATING RUN (85158157-853d-4c39-a9f2-341d434815d1): Termination message condition on agent 'User' met
# ✅ Extracted salary: 0-0-None-None
# ⏱️ Time used: 10.77 秒
#
# 🔍 Processing item 55:
#
# Next speaker: Planner
#
# Planner (to chat_manager):
#
# SALARY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Salary
#
# Salary (to chat_manager):
#
# 0-0-None-None
#
# --------------------------------------------------------------------------------
#
# Next speaker: Critic
#
# Critic (to chat_manager):
#
# TERMINATE
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (0e248458-1cb5-4992-84a9-06a00529b5de): Termination message condition on the GroupChatManager 'chat_manager' met
#
# >>>>>>>> TERMINATING RUN (0b3b1633-185d-4393-9b39-66345d6bfd87): Termination message condition on agent 'User' met
# ✅ Extracted salary: 0-0-None-None
# ⏱️ Time used: 10.01 秒
#
# 🔍 Processing item 56:
#
# Next speaker: Planner
#
# Planner (to chat_manager):
#
# SALARY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Salary
#
# Salary (to chat_manager):
#
# 0-0-None-None
#
# --------------------------------------------------------------------------------
#
# Next speaker: Critic
#
# Critic (to chat_manager):
#
# TERMINATE
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (d4f187c2-88fc-4991-a237-dfc16078667e): Termination message condition on the GroupChatManager 'chat_manager' met
#
# >>>>>>>> TERMINATING RUN (37830ed9-213c-47cb-b460-151de1aa0d60): Termination message condition on agent 'User' met
# ✅ Extracted salary: 0-0-None-None
# ⏱️ Time used: 8.81 秒
#
# 🔍 Processing item 57:
#
# Next speaker: Planner
#
# Planner (to chat_manager):
#
# SALARY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Salary
#
# Salary (to chat_manager):
#
# 15000-20000-PHP-MONTHLY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Critic
#
# Critic (to chat_manager):
#
# TERMINATE
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (f50d5dac-6486-4e23-927f-f53a2488d478): Termination message condition on the GroupChatManager 'chat_manager' met
#
# >>>>>>>> TERMINATING RUN (b64605a6-1cb1-41a9-815f-1406e62d873c): Termination message condition on agent 'User' met
# ✅ Extracted salary: 15000-20000-PHP-MONTHLY
# ⏱️ Time used: 6.27 秒
#
# 🔍 Processing item 58:
#
# Next speaker: Planner
#
# Planner (to chat_manager):
#
# SALARY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Salary
#
# Salary (to chat_manager):
#
# 0-0-None-None
#
# --------------------------------------------------------------------------------
#
# Next speaker: Critic
#
# Critic (to chat_manager):
#
# TERMINATE
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (319d0b20-cbc9-43b2-bbfc-367cbeed7023): Termination message condition on the GroupChatManager 'chat_manager' met
#
# >>>>>>>> TERMINATING RUN (bd6771b3-8de3-4f43-899f-1cdab28fe281): Termination message condition on agent 'User' met
# ✅ Extracted salary: 0-0-None-None
# ⏱️ Time used: 7.74 秒
#
# 🔍 Processing item 59:
#
# Next speaker: Planner
#
# Planner (to chat_manager):
#
# SALARY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Salary
#
# Salary (to chat_manager):
#
# 25-30-NZD-HOURLY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Critic
#
# Critic (to chat_manager):
#
# TERMINATE
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (957ec37c-7bbf-4026-81f9-5ba9e93eed91): Termination message condition on the GroupChatManager 'chat_manager' met
#
# >>>>>>>> TERMINATING RUN (acd94756-8e12-4019-a59c-b7436eaa61c8): Termination message condition on agent 'User' met
# ✅ Extracted salary: 25-30-NZD-HOURLY
# ⏱️ Time used: 6.71 秒
#
# 🔍 Processing item 60:
#
# Next speaker: Planner
#
# Planner (to chat_manager):
#
# SALARY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Salary
#
# Salary (to chat_manager):
#
# 0-0-None-None
#
# --------------------------------------------------------------------------------
#
# Next speaker: Critic
#
# Critic (to chat_manager):
#
# TERMINATE
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (a980532d-efcb-4de2-8157-4481ff1ea97d): Termination message condition on the GroupChatManager 'chat_manager' met
#
# >>>>>>>> TERMINATING RUN (fe2ffb81-ce95-4372-80d9-15e0088fd19e): Termination message condition on agent 'User' met
# ✅ Extracted salary: 0-0-None-None
# ⏱️ Time used: 12.44 秒
#
# 🔍 Processing item 61:
#
# Next speaker: Planner
#
# Planner (to chat_manager):
#
# SALARY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Salary
#
# Salary (to chat_manager):
#
# 3750-5000-PHP-MONTHLY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Critic
#
# Critic (to chat_manager):
#
# TERMINATE
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (c6dcf2f8-50fa-4541-9c89-e4cceb7b3703): Termination message condition on the GroupChatManager 'chat_manager' met
#
# >>>>>>>> TERMINATING RUN (2755fae4-20cb-47d7-aef1-1d8d576dfab6): Termination message condition on agent 'User' met
# ✅ Extracted salary: 3750-5000-PHP-MONTHLY
# ⏱️ Time used: 9.05 秒
#
# 🔍 Processing item 62:
#
# Next speaker: Planner
#
# Planner (to chat_manager):
#
# SALARY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Salary
#
# Salary (to chat_manager):
#
# 0-0-None-None
#
# --------------------------------------------------------------------------------
#
# Next speaker: Critic
#
# Critic (to chat_manager):
#
# TERMINATE
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (199245d6-1a06-40fe-bfa3-b49a6b43f30e): Termination message condition on the GroupChatManager 'chat_manager' met
#
# >>>>>>>> TERMINATING RUN (f61b75a9-b6e8-4b64-a64f-22e7e54760ce): Termination message condition on agent 'User' met
# ✅ Extracted salary: 0-0-None-None
# ⏱️ Time used: 15.34 秒
#
# 🔍 Processing item 63:
#
# Next speaker: Planner
#
# Planner (to chat_manager):
#
# SALARY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Salary
#
# Salary (to chat_manager):
#
# 1500-1500-MYR-MONTHLY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Critic
#
# Critic (to chat_manager):
#
# TERMINATE
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (067d7c5a-063a-4c66-85f9-fe8d7d119e78): Termination message condition on the GroupChatManager 'chat_manager' met
#
# ...
#
# Next speaker: Critic
#
# Critic (to chat_manager):
#
# TERMINATE
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (b1815a8a-a2ea-43dc-a50c-9398630c6061): Termination message condition on the GroupChatManager 'chat_manager' met
#
# >>>>>>>> TERMINATING RUN (2b0f9ec2-0462-4ff3-b3d3-8e64afef241a): Termination message condition on agent 'User' met
# ✅ Extracted salary: 0-0-None-None
# ⏱️ Time used: 7.10 秒
#
# 🔍 Processing item 549:
#
# Next speaker: Planner
#
# Planner (to chat_manager):
#
# SALARY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Salary
#
# Salary (to chat_manager):
#
# 15000-20000-PHP-MONTHLY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Critic
#
# Critic (to chat_manager):
#
# TERMINATE
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (76a7a67b-d1c2-4a60-8bcb-60ad90d87fd6): Termination message condition on the GroupChatManager 'chat_manager' met
#
# >>>>>>>> TERMINATING RUN (42f72aeb-5686-40d9-aa8b-05fa8a6b6e59): Termination message condition on agent 'User' met
# ✅ Extracted salary: 15000-20000-PHP-MONTHLY
# ⏱️ Time used: 10.05 秒
#
# 🔍 Processing item 550:
#
# Next speaker: Planner
#
# Planner (to chat_manager):
#
# SALARY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Salary
#
# Salary (to chat_manager):
#
# 0-0-None-None
#
# --------------------------------------------------------------------------------
#
# Next speaker: Critic
#
# Critic (to chat_manager):
#
# TERMINATE
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (b2ee5671-454c-4a94-aa7d-803f14e152aa): Termination message condition on the GroupChatManager 'chat_manager' met
#
# >>>>>>>> TERMINATING RUN (eda68ed6-2f9e-4fb1-9925-6b80c95aaf24): Termination message condition on agent 'User' met
# ✅ Extracted salary: 0-0-None-None
# ⏱️ Time used: 5.57 秒
#
# 🔍 Processing item 551:
#
# Next speaker: Planner
#
# Planner (to chat_manager):
#
# SALARY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Salary
#
# Salary (to chat_manager):
#
# 0-0-None-None
#
# --------------------------------------------------------------------------------
#
# Next speaker: Critic
#
# Critic (to chat_manager):
#
# TERMINATE
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (779c0a93-402e-4a44-94f1-ce32a16c73af): Termination message condition on the GroupChatManager 'chat_manager' met
#
# >>>>>>>> TERMINATING RUN (b933be9e-e7c6-41ee-a6dd-e58412d5df55): Termination message condition on agent 'User' met
# ✅ Extracted salary: 0-0-None-None
# ⏱️ Time used: 9.58 秒
#
# 🔍 Processing item 552:
#
# Next speaker: Planner
#
# Planner (to chat_manager):
#
# SALARY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Salary
#
# Salary (to chat_manager):
#
# 15000-20000-PHP-MONTHLY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Critic
#
# Critic (to chat_manager):
#
# TERMINATE
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (d5c83f8e-1c97-486c-a9c8-09b2eff59e7a): Termination message condition on the GroupChatManager 'chat_manager' met
#
# >>>>>>>> TERMINATING RUN (c6e7a5cc-c5f8-43b9-ac89-216886495640): Termination message condition on agent 'User' met
# ✅ Extracted salary: 15000-20000-PHP-MONTHLY
# ⏱️ Time used: 6.78 秒
#
# 🔍 Processing item 553:
#
# Next speaker: Planner
#
# Planner (to chat_manager):
#
# SALARY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Salary
#
# Salary (to chat_manager):
#
# 0-0-None-None
#
# --------------------------------------------------------------------------------
#
# Next speaker: Critic
#
# Critic (to chat_manager):
#
# TERMINATE
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (39a38224-b22c-4ecf-8631-b12f4df378a1): Termination message condition on the GroupChatManager 'chat_manager' met
#
# >>>>>>>> TERMINATING RUN (73d9668b-4100-44c1-a782-9ae0630cdf82): Termination message condition on agent 'User' met
# ✅ Extracted salary: 0-0-None-None
# ⏱️ Time used: 6.43 秒
#
# 🔍 Processing item 554:
#
# Next speaker: Planner
#
# Planner (to chat_manager):
#
# SALARY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Salary
#
# Salary (to chat_manager):
#
# 0-0-None-None
#
# --------------------------------------------------------------------------------
#
# Next speaker: Critic
#
# Critic (to chat_manager):
#
# TERMINATE
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (a330f50a-8bee-4877-bc3a-2d09b8cf0b47): Termination message condition on the GroupChatManager 'chat_manager' met
#
# >>>>>>>> TERMINATING RUN (5c87de71-dda1-45b8-9622-f3c1bfae9b6c): Termination message condition on agent 'User' met
# ✅ Extracted salary: 0-0-None-None
# ⏱️ Time used: 10.73 秒
#
# 🔍 Processing item 555:
#
# Next speaker: Planner
#
# Planner (to chat_manager):
#
# SALARY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Salary
#
# Salary (to chat_manager):
#
# 40.27-51.74-AUD-HOURLY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Critic
#
# Critic (to chat_manager):
#
# TERMINATE
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (c473c04a-36cc-468b-ac86-3b815f295501): Termination message condition on the GroupChatManager 'chat_manager' met
#
# >>>>>>>> TERMINATING RUN (2b1ce058-aef0-40ad-947f-b5cf186cfd9b): Termination message condition on agent 'User' met
# ✅ Extracted salary: 0-0-None-None
# ⏱️ Time used: 6.97 秒
#
# 🔍 Processing item 556:
#
# Next speaker: Planner
#
# Planner (to chat_manager):
#
# SALARY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Salary
#
# Salary (to chat_manager):
#
# 0-0-None-None
#
# --------------------------------------------------------------------------------
#
# Next speaker: Critic
#
# Critic (to chat_manager):
#
# TERMINATE
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (2e84d3d2-0306-44cf-a55a-0ca9b813d9e2): Termination message condition on the GroupChatManager 'chat_manager' met
#
# >>>>>>>> TERMINATING RUN (98671f46-8928-4acd-b00f-a820c2afc264): Termination message condition on agent 'User' met
# ✅ Extracted salary: 0-0-None-None
# ⏱️ Time used: 6.89 秒
#
# 🔍 Processing item 557:
#
# Next speaker: Planner
#
# Planner (to chat_manager):
#
# SALARY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Salary
#
# Salary (to chat_manager):
#
# 0-0-None-None
#
# --------------------------------------------------------------------------------
#
# Next speaker: Critic
#
# Critic (to chat_manager):
#
# TERMINATE
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (ae891f36-a405-41af-839c-37eb51089ece): Termination message condition on the GroupChatManager 'chat_manager' met
#
# >>>>>>>> TERMINATING RUN (4c6e8a73-3feb-413c-84ef-332bd3eb6abc): Termination message condition on agent 'User' met
# ✅ Extracted salary: 0-0-None-None
# ⏱️ Time used: 10.64 秒
#
# 🔍 Processing item 558:
#
# Next speaker: Planner
#
# Planner (to chat_manager):
#
# SALARY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Salary
#
# Salary (to chat_manager):
#
# 50-65-HKD-HOURLY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Critic
#
# Critic (to chat_manager):
#
# TERMINATE
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (1056e1ff-61c4-4593-a037-7a0ec37a7343): Termination message condition on the GroupChatManager 'chat_manager' met
#
# >>>>>>>> TERMINATING RUN (b2f39ba8-1f10-4b9c-a47c-ee4151b2ec4c): Termination message condition on agent 'User' met
# ✅ Extracted salary: 50-65-HKD-HOURLY
# ⏱️ Time used: 7.79 秒
#
# 🔍 Processing item 559:
#
# Next speaker: Planner
#
# Planner (to chat_manager):
#
# SALARY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Salary
#
# Salary (to chat_manager):
#
# 50-55-AUD-HOURLY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Critic
#
# Critic (to chat_manager):
#
# TERMINATE
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (54c81c41-52f9-4a57-a33b-c6be0a872c74): Termination message condition on the GroupChatManager 'chat_manager' met
#
# >>>>>>>> TERMINATING RUN (1b5c7e8d-5e09-4285-97d0-957b9412231d): Termination message condition on agent 'User' met
# ✅ Extracted salary: 50-55-AUD-HOURLY
# ⏱️ Time used: 13.07 秒
#
# 🔍 Processing item 560:
#
# Next speaker: Planner
#
# Planner (to chat_manager):
#
# SALARY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Salary
#
# Salary (to chat_manager):
#
# 0-0-None-None
#
# --------------------------------------------------------------------------------
#
# Next speaker: Critic
#
# Critic (to chat_manager):
#
# TERMINATE
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (797d87eb-050f-426f-a653-e79a6e763c75): Termination message condition on the GroupChatManager 'chat_manager' met
#
# >>>>>>>> TERMINATING RUN (b448749a-fd80-4bd6-aa0a-f025456badc8): Termination message condition on agent 'User' met
# ✅ Extracted salary: 0-0-None-None
# ⏱️ Time used: 7.38 秒
#
# 🔍 Processing item 561:
#
# Next speaker: Planner
#
# Planner (to chat_manager):
#
# SALARY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Salary
#
# Salary (to chat_manager):
#
# 0-0-None-None
#
# --------------------------------------------------------------------------------
#
# Next speaker: Critic
#
# Critic (to chat_manager):
#
# TERMINATE
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (0d0a7595-d095-47ca-a4fd-1f2ec2df0a98): Termination message condition on the GroupChatManager 'chat_manager' met
#
# >>>>>>>> TERMINATING RUN (a8e0ff8f-1bee-4716-b561-a1143d56b669): Termination message condition on agent 'User' met
# ✅ Extracted salary: 0-0-None-None
# ⏱️ Time used: 10.00 秒
#
# 🔍 Processing item 562:
#
# Next speaker: Planner
#
# Planner (to chat_manager):
#
# SALARY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Salary
#
# Salary (to chat_manager):
#
# 0-0-None-None
#
# --------------------------------------------------------------------------------
#
# Next speaker: Critic
#
# Critic (to chat_manager):
#
# TERMINATE
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (203f89fb-2dbf-4247-9bef-fdb74f1f9004): Termination message condition on the GroupChatManager 'chat_manager' met
#
# >>>>>>>> TERMINATING RUN (62a2eb10-1bfc-4b56-a99d-37b2df091f2f): Termination message condition on agent 'User' met
# ✅ Extracted salary: 0-0-None-None
# ⏱️ Time used: 6.97 秒
#
# 🔍 Processing item 563:
#
# Next speaker: Planner
#
# Planner (to chat_manager):
#
# SALARY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Salary
#
# Salary (to chat_manager):
#
# 26.24-26.24-NZD-HOURLY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Critic
#
# Critic (to chat_manager):
#
# TERMINATE
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (8cae5940-8140-4600-b1fd-cd82a3daba89): Termination message condition on the GroupChatManager 'chat_manager' met
#
# >>>>>>>> TERMINATING RUN (efc3808b-7a56-4052-b2d9-a9329b624611): Termination message condition on agent 'User' met
# ✅ Extracted salary: 0-0-None-None
# ⏱️ Time used: 5.55 秒
#
# 🔍 Processing item 564:
#
# Next speaker: Planner
#
# Planner (to chat_manager):
#
# SALARY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Salary
#
# Salary (to chat_manager):
#
# 0-0-None-None
#
# --------------------------------------------------------------------------------
#
# Next speaker: Critic
#
# Critic (to chat_manager):
#
# TERMINATE
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (34c83b4c-a908-4d91-b930-5ec6341c8ddf): Termination message condition on the GroupChatManager 'chat_manager' met
#
# >>>>>>>> TERMINATING RUN (b4f2d0a7-1855-4ace-be82-ff7f0636a147): Termination message condition on agent 'User' met
# ✅ Extracted salary: 0-0-None-None
# ⏱️ Time used: 8.23 秒
#
# 🔍 Processing item 565:
#
# Next speaker: Planner
#
# Planner (to chat_manager):
#
# SALARY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Salary
#
# Salary (to chat_manager):
#
# 0-0-None-None
#
# --------------------------------------------------------------------------------
#
# Next speaker: Critic
#
# Critic (to chat_manager):
#
# TERMINATE
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (390b712e-5e6b-4b25-87de-01a5e7788431): Termination message condition on the GroupChatManager 'chat_manager' met
#
# >>>>>>>> TERMINATING RUN (dcbc4bac-f95a-47ef-bdb3-ae2cde488085): Termination message condition on agent 'User' met
# ✅ Extracted salary: 0-0-None-None
# ⏱️ Time used: 8.78 秒
#
# 🔍 Processing item 566:
#
# Next speaker: Planner
#
# Planner (to chat_manager):
#
# SALARY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Salary
#
# Salary (to chat_manager):
#
# 1500-2500-MYR-MONTHLY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Critic
#
# Critic (to chat_manager):
#
# TERMINATE
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (de71cb0b-d61f-4671-b1dd-4491eb2684ff): Termination message condition on the GroupChatManager 'chat_manager' met
#
# >>>>>>>> TERMINATING RUN (c64beb34-75af-4b82-84fb-f12aae022872): Termination message condition on agent 'User' met
# ✅ Extracted salary: 1500-2500-MYR-MONTHLY
# ⏱️ Time used: 8.53 秒
#
# 🔍 Processing item 567:
#
# Next speaker: Planner
#
# Planner (to chat_manager):
#
# SALARY
#
# --------------------------------------------------------------------------------
#
# Next speaker: Salary
#
# Salary (to chat_manager):
#
# 0-0-None-None
#
# --------------------------------------------------------------------------------
#
# Next speaker: Critic
#
# Critic (to chat_manager):
#
# TERMINATE
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (da4fee44-f7d1-4c79-bbbd-8aa388645452): Termination message condition on the GroupChatManager 'chat_manager' met
#
# >>>>>>>> TERMINATING RUN (f2158c8e-f102-45a6-bb48-075014644190): Termination message condition on agent 'User' met
# ✅ Extracted salary: 0-0-None-None
# ⏱️ Time used: 6.08 秒
#
# 📋 Results Table:
#      index                 y_true            y_predicted time_seconds
# 0        0  1500-1800-MYR-MONTHLY  1500-1800-MYR-MONTHLY         6.03
# 1        1       60-60-HKD-HOURLY       60-60-HKD-HOURLY         9.58
# 2        2          0-0-None-None          0-0-None-None         7.68
# 3        3          0-0-None-None          0-0-None-None        10.46
# 4        4          0-0-None-None          0-0-None-None         8.36
# ..     ...                    ...                    ...          ...
# 562    562       26-26-NZD-HOURLY          0-0-None-None         5.55
# 563    563          0-0-None-None          0-0-None-None         8.23
# 564    564          0-0-None-None          0-0-None-None         8.78
# 565    565  1500-2500-MYR-MONTHLY  1500-2500-MYR-MONTHLY         8.53
# 566    566          0-0-None-None          0-0-None-None         6.08
#
# [567 rows x 4 columns]
#
# ⏱️ 总耗时：4399.68 秒 (73.33 分钟)
